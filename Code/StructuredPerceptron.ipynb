# %%
from random import shuffle
import pandas as pd
import numpy as np
from stemming.porter2 import stem

# %%
class structuredPerceptron():
    def __init__(self,learningRate=0.001,C=0.1):
        self.weight={}
        self.avg={}
        self.gamma=learningRate
        self.C=C
        
    """sentence and label will be the lists""" 

    def featureExt(self,sentence,label):           
        featureVect={}
        #emission features
        if (not isinstance(sentence,list)):
            sentence=[''.join(sentence)]
        if (not isinstance(label,list)):
            label=[''.join(label)]
#         print sentence, label
        if len(label)==len(sentence):
#             print sentence, label
            emission=zip(sentence,label)
#             print emission
            for feat in emission:
#                 print 'feat tuple: ', feat
                key =str(feat[0]+'_'+feat[1])
                if featureVect.has_key(key):
                    featureVect[key]+=1
                else:
                    featureVect[key]=1
                
            #transition features
            
            transitionsLavel1=[]
#             print 'label: ', label
            if len(label)==1:
                transitionsLavel1.append('start'+'_'+label[0])
            else:
                transitionsLavel1=[str(label[i]+'_'+label[i+1]) for i in range(len(label)-1)]
                transitionsLavel1.append('start'+'_'+label[0])
                transitionsLavel1.append('end'+'_'+label[-1])

            for trans in transitionsLavel1:
                key = trans
                if featureVect.has_key(key):
                    featureVect[key]+=1
                else:
                    featureVect[key]=1
            
            
            #transition emission feature
            transitionsLavel2=[]
#             print 'label: ', label
            if len(label)==1:
                transitionsLavel2.append('start'+'_'+label[0]+'_'+sentence[0])
            else:
                transitionsLavel2=[str(label[i]+'_'+label[i+1]+'_'+sentence[i+1]) for i in range(len(label)-1)]
                transitionsLavel2.append('start'+'_'+label[0]+'_'+sentence[1])
                transitionsLavel2.append('end'+'_'+label[-1]+'_'+sentence[-1])

            for trans in transitionsLavel2:
                key = trans
                if featureVect.has_key(key):
                    featureVect[key]+=1
                else:
                    featureVect[key]=1
                    
                    
            
        return featureVect

    
    def score(self,featureVect):
        summ=0
        for key, value in featureVect.iteritems():
            if self.weight.has_key(key):
                summ+=self.weight[key]*featureVect[key]
            else:
                self.weight[key]=0
        return summ
    
    
    def findQty(self,inp):
        qtySFound=False
        qtyEFound=False
        fractions={'1/2':0.5,'3/4':0.75,'1/4':0.25,'1/8':0.125,'1/3':0.33,'2/3':0.66}
        qtys=0
        qtye=0
        word=inp
        i=0
    #     print inp
        label_array=[None]*len(inp)
        while(i < len(inp)):
            if not qtySFound and i<len(inp)-1:
                if word[i].isdigit() or word[i] in fractions.keys():
                    qtySFound=True
                    if word[i] in fractions.keys():
                        qtys=fractions[word[i]]
                        index=i
                        label_array[i]='qtys'
                    else:
                        qtys=int(word[i])
                        label_array[i]='qtys'
                        if word[i+1] in fractions.keys():
                            qtys=qtys+fractions[word[i+1]]
                            label_array[i+1]='qtys'
                            i=i+1   
                            index=i+1
                        else:
                            index=i


                    i=i+1
                    continue

            if not qtyEFound and i<len(inp)-1 and qtySFound:
                if i>(index+1):
                    break

                if word[i].isdigit() or word[i] in fractions.keys() :
                    qtyEFound=True
                    if word[i] in fractions.keys():
                        qtye=fractions[word[i]]
                        label_array[i]='qtye'
                    else:
                        qtye=int(word[i])
                        label_array[i]='qtye'
                        if word[i+1] in fractions.keys():
                            qtye=qtye+fractions[word[i+1]]
                            label_array[i+1]='qtye'

            if qtySFound and qtyEFound:
                break

            i=i+1
        return label_array

    
    def viterbiRaw(self,inp,DEBUG=False):
        alpha1=[]
        alpha2=[]
        alpha3=[]
        
        labelmap={
            0:'name',
            1:'unit',
            2:'comment'        
        }
        alphamap={
            0:alpha1,
            1:alpha2,
            2:alpha3        
        }
        
        label=self.findQty(inp)
#         print label

        if label.count(None)<=len(inp):
            viterbi_table=np.zeros((3,len(inp)))
            backpointer=np.zeros((3,len(inp)))

            k=0;
            while(label[k]=='qtys' or label[k]=='qtye'):
                if label[k]=='qtys':
                        alpha1.append('qtys')
                        alpha2.append('qtys')
                        alpha3.append('qtys')
                        
                else:
                    alpha1.append('qtye')
                    alpha2.append('qtye')
                    alpha3.append('qtye')
                backpointer[0][k] = 0;
                backpointer[1][k] = 1;
                backpointer[2][k] = 2;
                k=k+1;

    #         print k, label[k]
           
            
            viterbi_table[0][k]= self.score(self.featureExt(inp[0:k+1],alpha1+['name']))
            alpha1.append('name')
            viterbi_table[1][k]= self.score(self.featureExt(inp[0:k+1],alpha2+['unit']))
            alpha2.append('unit')
            viterbi_table[2][k]= self.score(self.featureExt(inp[0:k+1],alpha3+['comment']))
            alpha3.append('comment')
            if DEBUG:
                print 'before: ', alpha1, alpha2,alpha3
            for j in range(k+1,len(inp)):
                
                #Assumes previous column was something else
                if label[j]=='qtys' or label[j]=='qtye':
                    if label[j]=='qtys':
                        alpha1.append('qtys')
                        alpha2.append('qtys')
                        alpha3.append('qtys')
                        
                    else:
                        alpha1.append('qtye')
                        alpha2.append('qtye')
                        alpha3.append('qtye')
                    viterbi_table[0][j] = viterbi_table[0][j-1];
                    viterbi_table[1][j] = viterbi_table[1][j-1];
                    viterbi_table[2][j] = viterbi_table[2][j-1];
                    backpointer[0][j] = backpointer[0][j-1];
                    backpointer[1][j] = backpointer[1][j-1];
                    backpointer[2][j] = backpointer[2][j-1];
                    
                else:
                    if(j!=0):   
                        alphamap={
                            0:alpha1,
                            1:alpha2,
                            2:alpha3        
                        }
                        max1=[self.score(self.featureExt(inp[0:j+1],alpha1+['name'])), self.score(self.featureExt(inp[0:j+1],alpha2+['name'])),self.score(self.featureExt(inp[0:j+1],alpha3+['name']))]
                        viterbi_table[0][j]=max(max1)
                        backpointer[0][j]=max1.index(max(max1))
                        if DEBUG:
                            print 'input: \n',inp[0:j+1]
                            
                            print 'max1: \n',max1


                        max2=[self.score(self.featureExt(inp[0:j+1],alpha1+['unit'])), self.score(self.featureExt(inp[0:j+1],alpha2+['unit'])),self.score(self.featureExt(inp[0:j+1],alpha3+['unit']))]
                        viterbi_table[1][j]=max(max2)
                        backpointer[1][j]=max2.index(max(max2))
                        if DEBUG:
                            print 'max2: \n',max2


                        max3=[self.score(self.featureExt(inp[0:j+1],alpha1+['comment'])), self.score(self.featureExt(inp[0:j+1],alpha2+['comment'])),self.score(self.featureExt(inp[0:j+1],alpha3+['comment']))]
                        viterbi_table[2][j]=max(max3)
                        backpointer[2][j]=max3.index(max(max3))
                        if DEBUG:
                            print 'max3: \n',max3

                        temp1=list(alphamap[max1.index(max(max1))])
                        temp1.append('name')
                        temp2=list(alphamap[max2.index(max(max2))])
                        temp2.append('unit')
                        temp3=list(alphamap[max3.index(max(max3))])
                        temp3.append('comment') 
                        
                        alpha1=list(temp1)
                        alpha2=list(temp2)
                        alpha3=list(temp3) 
                        if DEBUG:                 
                            print 'alpha at ',j,'th step: \n', alpha1, alpha2,alpha3
                   

            last_col=viterbi_table[:,-1]
            back=np.argmax(last_col)
            label[-1]=labelmap[np.argmax(last_col)]

            for h in range(len(inp)-2,-1,-1):
                if(label[h]==None):
                    label[h]=labelmap[backpointer[back][h+1]]
                back=backpointer[back][h]
        return viterbi_table,backpointer, label

    
    
    
   
    
    def predict(self,sentence,test=False):
        if test:
            DEBUG=True
            self.weight=self.avg
            viterbi_table,backpointer, labelPredicted=self.viterbiRaw(sentence,DEBUG)
            print 'viterbi table',viterbi_table
            print 'backpointer: ',backpointer
        else: 
            viterbi_table,backpointer, labelPredicted=self.viterbiRaw(sentence)
        return labelPredicted
            
    
    def train(self,data):        
        for j in range(10):  #Number of epochs=10 
            shuffle(data)
            i=1
            
            for sent in data:
                gamma_t=self.gamma*1.0/(1+self.gamma*self.C*i)
                i+=1
                if i%500==0:
                    print 'Epoch: ',j, '  input :',i
                sentence=sent[0]
                labelTrain=sent[1]
                labelPredicted=self.predict(sentence)                

                features1=self.featureExt(sentence,labelTrain) #correct
                features2=self.featureExt(sentence,labelPredicted) #prediction
                featureCombined={}
               
            #update on mistake
                for key,value in features1.iteritems():
                    if not self.weight.has_key(key):
                        self.weight[key]=0  #add to weight vector 
                    if features2.has_key(key):
                        featureCombined[key]=features1[key]-features2[key]
                    else:
                        featureCombined[key]=features1[key]

                for key,value in features2.iteritems():
                    if not self.weight.has_key(key):
                        self.weight[key]=0
                    if not features1.has_key(key) :
                        featureCombined[key]=-1*features2[key]

                
                for key,value in featureCombined.iteritems():
                    self.weight[key]+=gamma_t*featureCombined[key]
                
                for key,value in self.weight.iteritems():
                    if self.avg.has_key(key):
                        self.avg[key]+=self.weight[key]
                    else:
                        self.avg[key]=self.weight[key]
        
        
    
    def test(self,sentence,test=False):
        label=self.predict(sentence,test)
        return label

# %% [markdown]
# # Input

# %%
data= pd.read_csv('../nyt_training.csv')
with open('../stopwords.txt','r') as f:
    stopwords=f.readlines()
    stopwords=[word.strip('\n') for word in stopwords]

input_col=data['input']
# input_col=[nm.strip('\n') for nm in input_col]
input_col=[str(nm).lower() for nm in input_col]
input_col=[nm.split(' ') for nm in input_col]
input_col=[[word.strip('\t') for word in nm] for nm in input_col]
input_col=[[word.strip('_') for word in nm] for nm in input_col]
input_col=[[word.strip(',') for word in nm] for nm in input_col]
input_col=[[word.strip('/') for word in nm] for nm in input_col]
input_col=[[word.strip(')') for word in nm] for nm in input_col]
input_col=[[word.strip('(') for word in nm] for nm in input_col]
input_col=[[word.strip("'") for word in nm] for nm in input_col]
input_col=[[word.strip('\n') for word in nm] for nm in input_col]
# input_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in input_col]
input_col=[[stem(word) for word in ls] for ls in input_col]
# input_col=[[word for word in ls] for ls in input_col]
# input_col

name_col=data['name']
nameCountMap={}
name_col=[str(nm).lower() for nm in name_col]
name_col=[nm.split(' ') for nm in name_col]
name_col=[[word.strip('\t') for word in nm] for nm in name_col]
name_col=[[word.strip(' ') for word in nm] for nm in name_col]
name_col=[[word.strip(',') for word in nm] for nm in name_col]
name_col=[[word.strip('/') for word in nm] for nm in name_col]
name_col=[[word.strip(')') for word in nm] for nm in name_col]
name_col=[[word.strip('(') for word in nm] for nm in name_col]
name_col=[[word.strip("'") for word in nm] for nm in name_col]
name_col=[[word.strip('\n') for word in nm] for nm in name_col]
# name_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in name_col]
name_col=[[stem(word) for word in ls ] for ls in name_col]
word_list_name=[word for ls in name_col for word in ls]


unit_col=data['unit']
unit_col=[str(nm).lower() for nm in unit_col]
unit_col=[nm.split(' ') for nm in unit_col]
unit_col=[[word.strip('\t') for word in nm] for nm in unit_col]
unit_col=[[word.strip(' ') for word in nm]for nm in unit_col]
unit_col=[[word.strip(',') for word in nm] for nm in unit_col]
unit_col=[[word.strip('/') for word in nm] for nm in unit_col]
unit_col=[[word.strip(')') for word in nm] for nm in unit_col]
unit_col=[[word.strip('(') for word in nm] for nm in unit_col]
unit_col=[[word.strip("'") for word in nm] for nm in unit_col]
unit_col=[[word.strip('\n') for word in nm] for nm in unit_col]
# unit_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in unit_col]
unit_col=[[stem(word) for word in ls ] for ls in unit_col]
word_list_unit=[word for ls in unit_col for word in ls]# unit_col


comment_col=data['comment']
comment_col=[str(nm).lower() for nm in comment_col]
comment_col=[nm.split(' ') for nm in comment_col]
comment_col=[[word.strip('\t') for word in nm] for nm in comment_col]
comment_col=[[word.strip(' ') for word in nm] for nm in comment_col]
comment_col=[[word.strip(',') for word in nm] for nm in comment_col]
comment_col=[[word.strip('/') for word in nm] for nm in comment_col]
comment_col=[[word.strip(')') for word in nm] for nm in comment_col]
comment_col=[[word.strip('(') for word in nm] for nm in comment_col]
comment_col=[[word.strip("'") for word in nm] for nm in comment_col]
comment_col=[[word.strip('\n') for word in nm] for nm in comment_col]
# comment_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in comment_col]
comment_col=[[stem(word) for word in ls ] for ls in comment_col]
word_list_comment=[word for ls in comment_col for word in ls]

qtys_col=data['qty']
qtys_col=[nm for nm in qtys_col]

qtye_col=data['range_end']
qtye_col=[nm for nm in qtye_col]

# %%
def correctLabels(index,label):
    for i in range(len(label)):
        if label[i] not in ['qtys','qtye']:
            if input_col[index][i] in name_col[index]:
                label[i]='name'
            
            elif input_col[index][i] in unit_col[index]:
                label[i]='unit'
                
#             elif input_col[index][i] in comment_col[index]:
#                 label[i]='comment'
            else:
                label[i]='comment'
        
        
                
    return label

# %%
sp= structuredPerceptron(learningRate=0.01)

datalabels=[sp.findQty(sent) for sent in input_col]
datalabels=[correctLabels(i,datalabels[i]) for i in range(len(datalabels))]
# print datalabels[4]                
data=zip(input_col,datalabels)

sp.train(data)


# print sp.featureExt(['1/4', 'cup', 'extra-virgin', 'oliv', 'oil'], ['qtys', 'unit', 'comment', 'name', 'name'])
# print data[2:3]
# Out:
# C:\Users\SANKET\Anaconda2\envs\myenv\lib\site-packages\ipykernel_launcher.py:256: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# C:\Users\SANKET\Anaconda2\envs\myenv\lib\site-packages\ipykernel_launcher.py:257: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# Epoch:  0   input : 500
# Epoch:  0   input : 1000
# Epoch:  0   input : 1500
# Epoch:  0   input : 2000
# Epoch:  0   input : 2500
# Epoch:  0   input : 3000
# Epoch:  0   input : 3500
# Epoch:  0   input : 4000
# Epoch:  0   input : 4500
# Epoch:  0   input : 5000
# Epoch:  0   input : 5500
# Epoch:  0   input : 6000
# Epoch:  0   input : 6500
# Epoch:  0   input : 7000
# Epoch:  0   input : 7500
# Epoch:  0   input : 8000
# Epoch:  0   input : 8500
# Epoch:  0   input : 9000
# Epoch:  0   input : 9500
# Epoch:  0   input : 10000
# Epoch:  0   input : 10500
# Epoch:  0   input : 11000
# Epoch:  0   input : 11500
# Epoch:  0   input : 12000
# Epoch:  0   input : 12500
# Epoch:  0   input : 13000
# Epoch:  0   input : 13500
# Epoch:  0   input : 14000
# Epoch:  0   input : 14500
# Epoch:  0   input : 15000
# Epoch:  0   input : 15500
# Epoch:  0   input : 16000
# Epoch:  0   input : 16500
# Epoch:  0   input : 17000
# Epoch:  0   input : 17500
# Epoch:  0   input : 18000
# Epoch:  0   input : 18500
# Epoch:  0   input : 19000
# Epoch:  0   input : 19500
# Epoch:  0   input : 20000
# Epoch:  0   input : 20500
# Epoch:  0   input : 21000
# Epoch:  0   input : 21500
# Epoch:  0   input : 22000
# Epoch:  0   input : 22500
# Epoch:  0   input : 23000
# Epoch:  0   input : 23500
# Epoch:  0   input : 24000
# Epoch:  0   input : 24500
# Epoch:  0   input : 25000
# Epoch:  0   input : 25500
# Epoch:  0   input : 26000
# Epoch:  0   input : 26500
# Epoch:  0   input : 27000
# Epoch:  0   input : 27500
# Epoch:  0   input : 28000
# Epoch:  0   input : 28500
# Epoch:  0   input : 29000
# Epoch:  0   input : 29500
# Epoch:  0   input : 30000
# Epoch:  0   input : 30500
# Epoch:  0   input : 31000
# Epoch:  0   input : 31500
# Epoch:  0   input : 32000
# Epoch:  0   input : 32500
# Epoch:  0   input : 33000
# Epoch:  0   input : 33500
# Epoch:  0   input : 34000
# Epoch:  0   input : 34500
# Epoch:  0   input : 35000
# Epoch:  0   input : 35500
# Epoch:  0   input : 36000
# Epoch:  0   input : 36500
# Epoch:  0   input : 37000
# Epoch:  0   input : 37500
# Epoch:  0   input : 38000
# Epoch:  0   input : 38500
# Epoch:  0   input : 39000
# Epoch:  0   input : 39500
# Epoch:  0   input : 40000
# Epoch:  0   input : 40500
# Epoch:  0   input : 41000
# Epoch:  0   input : 41500
# Epoch:  0   input : 42000
# Epoch:  0   input : 42500
# Epoch:  0   input : 43000
# Epoch:  0   input : 43500
# Epoch:  0   input : 44000
# Epoch:  0   input : 44500
# Epoch:  0   input : 45000
# Epoch:  0   input : 45500
# Epoch:  0   input : 46000
# Epoch:  0   input : 46500
# Epoch:  0   input : 47000
# Epoch:  0   input : 47500
# Epoch:  0   input : 48000
# Epoch:  0   input : 48500
# Epoch:  0   input : 49000
# Epoch:  0   input : 49500
# Epoch:  0   input : 50000
# Epoch:  0   input : 50500
# Epoch:  0   input : 51000
# Epoch:  0   input : 51500
# Epoch:  0   input : 52000
# Epoch:  0   input : 52500
# Epoch:  0   input : 53000
# Epoch:  0   input : 53500
# Epoch:  0   input : 54000
# Epoch:  0   input : 54500
# Epoch:  0   input : 55000
# Epoch:  0   input : 55500
# Epoch:  0   input : 56000
# Epoch:  0   input : 56500
# Epoch:  0   input : 57000
# Epoch:  0   input : 57500
# Epoch:  0   input : 58000
# Epoch:  0   input : 58500
# Epoch:  0   input : 59000
# Epoch:  0   input : 59500
# Epoch:  0   input : 60000
# Epoch:  0   input : 60500
# Epoch:  0   input : 61000
# Epoch:  0   input : 61500
# Epoch:  0   input : 62000
# Epoch:  0   input : 62500
# Epoch:  0   input : 63000
# Epoch:  0   input : 63500
# Epoch:  0   input : 64000
# Epoch:  0   input : 64500
# Epoch:  0   input : 65000
# Epoch:  0   input : 65500
# Epoch:  0   input : 66000
# Epoch:  0   input : 66500
# Epoch:  0   input : 67000
# Epoch:  0   input : 67500
# Epoch:  0   input : 68000
# Epoch:  0   input : 68500
# Epoch:  0   input : 69000
# Epoch:  0   input : 69500
# Epoch:  0   input : 70000
# Epoch:  0   input : 70500
# Epoch:  0   input : 71000
# Epoch:  0   input : 71500
# Epoch:  0   input : 72000
# Epoch:  0   input : 72500
# Epoch:  0   input : 73000
# Epoch:  0   input : 73500
# Epoch:  0   input : 74000
# Epoch:  0   input : 74500
# Epoch:  0   input : 75000
# Epoch:  0   input : 75500
# Epoch:  0   input : 76000
# Epoch:  0   input : 76500
# Epoch:  0   input : 77000
# Epoch:  0   input : 77500
# Epoch:  0   input : 78000
# Epoch:  0   input : 78500
# Epoch:  0   input : 79000
# Epoch:  0   input : 79500
# Epoch:  0   input : 80000
# Epoch:  0   input : 80500
# Epoch:  0   input : 81000
# Epoch:  0   input : 81500
# Epoch:  0   input : 82000
# Epoch:  0   input : 82500
# Epoch:  0   input : 83000
# Epoch:  0   input : 83500
# Epoch:  0   input : 84000
# Epoch:  0   input : 84500
# Epoch:  0   input : 85000
# Epoch:  0   input : 85500
# Epoch:  0   input : 86000
# Epoch:  0   input : 86500
# Epoch:  0   input : 87000
# Epoch:  0   input : 87500
# Epoch:  0   input : 88000
# Epoch:  0   input : 88500
# Epoch:  0   input : 89000
# Epoch:  0   input : 89500
# Epoch:  0   input : 90000
# Epoch:  0   input : 90500
# Epoch:  0   input : 91000
# Epoch:  0   input : 91500
# Epoch:  0   input : 92000
# Epoch:  0   input : 92500
# Epoch:  0   input : 93000
# Epoch:  0   input : 93500
# Epoch:  0   input : 94000
# Epoch:  0   input : 94500
# Epoch:  0   input : 95000
# Epoch:  0   input : 95500
# Epoch:  0   input : 96000
# Epoch:  0   input : 96500
# Epoch:  0   input : 97000
# Epoch:  0   input : 97500
# Epoch:  0   input : 98000
# Epoch:  0   input : 98500
# Epoch:  0   input : 99000
# Epoch:  0   input : 99500
# Epoch:  0   input : 100000
# Epoch:  0   input : 100500
# Epoch:  0   input : 101000
# Epoch:  0   input : 101500
# Epoch:  0   input : 102000
# Epoch:  0   input : 102500
# Epoch:  0   input : 103000
# Epoch:  0   input : 103500
# Epoch:  0   input : 104000
# Epoch:  0   input : 104500
# Epoch:  0   input : 105000
# Epoch:  0   input : 105500
# Epoch:  0   input : 106000
# Epoch:  0   input : 106500
# Epoch:  0   input : 107000
# Epoch:  0   input : 107500
# Epoch:  0   input : 108000
# Epoch:  0   input : 108500
# Epoch:  0   input : 109000
# Epoch:  0   input : 109500
# Epoch:  0   input : 110000
# Epoch:  0   input : 110500
# Epoch:  0   input : 111000
# Epoch:  0   input : 111500
# Epoch:  0   input : 112000
# Epoch:  0   input : 112500
# Epoch:  0   input : 113000
# Epoch:  0   input : 113500
# Epoch:  0   input : 114000
# Epoch:  0   input : 114500
# Epoch:  0   input : 115000
# Epoch:  0   input : 115500
# Epoch:  0   input : 116000
# Epoch:  0   input : 116500
# Epoch:  0   input : 117000
# Epoch:  0   input : 117500
# Epoch:  0   input : 118000
# Epoch:  0   input : 118500
# Epoch:  0   input : 119000
# Epoch:  0   input : 119500
# Epoch:  0   input : 120000
# Epoch:  0   input : 120500
# Epoch:  0   input : 121000
# Epoch:  0   input : 121500
# Epoch:  0   input : 122000
# Epoch:  0   input : 122500
# Epoch:  0   input : 123000
# Epoch:  0   input : 123500
# Epoch:  0   input : 124000
# Epoch:  0   input : 124500
# Epoch:  0   input : 125000
# Epoch:  0   input : 125500
# Epoch:  1   input : 500
# Epoch:  1   input : 1000
# Epoch:  1   input : 1500
# Epoch:  1   input : 2000
# Epoch:  1   input : 2500
# Epoch:  1   input : 3000
# Epoch:  1   input : 3500
# Epoch:  1   input : 4000
# Epoch:  1   input : 4500
# Epoch:  1   input : 5000
# Epoch:  1   input : 5500
# Epoch:  1   input : 6000
# Epoch:  1   input : 6500
# Epoch:  1   input : 7000
# Epoch:  1   input : 7500
# Epoch:  1   input : 8000
# Epoch:  1   input : 8500
# Epoch:  1   input : 9000
# Epoch:  1   input : 9500
# Epoch:  1   input : 10000
# Epoch:  1   input : 10500
# Epoch:  1   input : 11000
# Epoch:  1   input : 11500
# Epoch:  1   input : 12000
# Epoch:  1   input : 12500
# Epoch:  1   input : 13000
# Epoch:  1   input : 13500
# Epoch:  1   input : 14000
# Epoch:  1   input : 14500
# Epoch:  1   input : 15000
# Epoch:  1   input : 15500
# Epoch:  1   input : 16000
# Epoch:  1   input : 16500
# Epoch:  1   input : 17000
# Epoch:  1   input : 17500
# Epoch:  1   input : 18000
# Epoch:  1   input : 18500
# Epoch:  1   input : 19000
# Epoch:  1   input : 19500
# Epoch:  1   input : 20000
# Epoch:  1   input : 20500
# Epoch:  1   input : 21000
# Epoch:  1   input : 21500
# Epoch:  1   input : 22000
# Epoch:  1   input : 22500
# Epoch:  1   input : 23000
# Epoch:  1   input : 23500
# Epoch:  1   input : 24000
# Epoch:  1   input : 24500
# Epoch:  1   input : 25000
# Epoch:  1   input : 25500
# Epoch:  1   input : 26000
# Epoch:  1   input : 26500
# Epoch:  1   input : 27000
# Epoch:  1   input : 27500
# Epoch:  1   input : 28000
# Epoch:  1   input : 28500
# Epoch:  1   input : 29000
# Epoch:  1   input : 29500
# Epoch:  1   input : 30000
# Epoch:  1   input : 30500
# Epoch:  1   input : 31000
# Epoch:  1   input : 31500
# Epoch:  1   input : 32000
# Epoch:  1   input : 32500
# Epoch:  1   input : 33000
# Epoch:  1   input : 33500
# Epoch:  1   input : 34000
# Epoch:  1   input : 34500
# Epoch:  1   input : 35000
# Epoch:  1   input : 35500
# Epoch:  1   input : 36000
# Epoch:  1   input : 36500
# Epoch:  1   input : 37000
# Epoch:  1   input : 37500
# Epoch:  1   input : 38000
# Epoch:  1   input : 38500
# Epoch:  1   input : 39000
# Epoch:  1   input : 39500
# Epoch:  1   input : 40000
# Epoch:  1   input : 40500
# Epoch:  1   input : 41000
# Epoch:  1   input : 41500
# Epoch:  1   input : 42000
# Epoch:  1   input : 42500
# Epoch:  1   input : 43000
# Epoch:  1   input : 43500
# Epoch:  1   input : 44000
# Epoch:  1   input : 44500
# Epoch:  1   input : 45000
# Epoch:  1   input : 45500
# Epoch:  1   input : 46000
# Epoch:  1   input : 46500
# Epoch:  1   input : 47000
# Epoch:  1   input : 47500
# Epoch:  1   input : 48000
# Epoch:  1   input : 48500
# Epoch:  1   input : 49000
# Epoch:  1   input : 49500
# Epoch:  1   input : 50000
# Epoch:  1   input : 50500
# Epoch:  1   input : 51000
# Epoch:  1   input : 51500
# Epoch:  1   input : 52000
# Epoch:  1   input : 52500
# Epoch:  1   input : 53000
# Epoch:  1   input : 53500
# Epoch:  1   input : 54000
# Epoch:  1   input : 54500
# Epoch:  1   input : 55000
# Epoch:  1   input : 55500
# Epoch:  1   input : 56000
# Epoch:  1   input : 56500
# Epoch:  1   input : 57000
# Epoch:  1   input : 57500
# Epoch:  1   input : 58000
# Epoch:  1   input : 58500
# Epoch:  1   input : 59000
# Epoch:  1   input : 59500
# Epoch:  1   input : 60000
# Epoch:  1   input : 60500
# Epoch:  1   input : 61000
# Epoch:  1   input : 61500
# Epoch:  1   input : 62000
# Epoch:  1   input : 62500
# Epoch:  1   input : 63000
# Epoch:  1   input : 63500
# Epoch:  1   input : 64000
# Epoch:  1   input : 64500
# Epoch:  1   input : 65000
# Epoch:  1   input : 65500
# Epoch:  1   input : 66000
# Epoch:  1   input : 66500
# Epoch:  1   input : 67000
# Epoch:  1   input : 67500
# Epoch:  1   input : 68000
# Epoch:  1   input : 68500
# Epoch:  1   input : 69000
# Epoch:  1   input : 69500
# Epoch:  1   input : 70000
# Epoch:  1   input : 70500
# Epoch:  1   input : 71000
# Epoch:  1   input : 71500
# Epoch:  1   input : 72000
# Epoch:  1   input : 72500
# Epoch:  1   input : 73000
# Epoch:  1   input : 73500
# Epoch:  1   input : 74000
# Epoch:  1   input : 74500
# Epoch:  1   input : 75000
# Epoch:  1   input : 75500
# Epoch:  1   input : 76000
# Epoch:  1   input : 76500
# Epoch:  1   input : 77000
# Epoch:  1   input : 77500
# Epoch:  1   input : 78000
# Epoch:  1   input : 78500
# Epoch:  1   input : 79000
# Epoch:  1   input : 79500
# Epoch:  1   input : 80000
# Epoch:  1   input : 80500
# Epoch:  1   input : 81000
# Epoch:  1   input : 81500
# Epoch:  1   input : 82000
# Epoch:  1   input : 82500
# Epoch:  1   input : 83000
# Epoch:  1   input : 83500
# Epoch:  1   input : 84000
# Epoch:  1   input : 84500
# Epoch:  1   input : 85000
# Epoch:  1   input : 85500
# Epoch:  1   input : 86000
# Epoch:  1   input : 86500
# Epoch:  1   input : 87000
# Epoch:  1   input : 87500
# Epoch:  1   input : 88000
# Epoch:  1   input : 88500
# Epoch:  1   input : 89000
# Epoch:  1   input : 89500
# Epoch:  1   input : 90000
# Epoch:  1   input : 90500
# Epoch:  1   input : 91000
# Epoch:  1   input : 91500
# Epoch:  1   input : 92000
# Epoch:  1   input : 92500
# Epoch:  1   input : 93000
# Epoch:  1   input : 93500
# Epoch:  1   input : 94000
# Epoch:  1   input : 94500
# Epoch:  1   input : 95000
# Epoch:  1   input : 95500
# Epoch:  1   input : 96000
# Epoch:  1   input : 96500
# Epoch:  1   input : 97000
# Epoch:  1   input : 97500
# Epoch:  1   input : 98000
# Epoch:  1   input : 98500
# Epoch:  1   input : 99000
# Epoch:  1   input : 99500
# Epoch:  1   input : 100000
# Epoch:  1   input : 100500
# Epoch:  1   input : 101000
# Epoch:  1   input : 101500
# Epoch:  1   input : 102000
# Epoch:  1   input : 102500
# Epoch:  1   input : 103000
# Epoch:  1   input : 103500
# Epoch:  1   input : 104000
# Epoch:  1   input : 104500
# Epoch:  1   input : 105000
# Epoch:  1   input : 105500
# Epoch:  1   input : 106000
# Epoch:  1   input : 106500
# Epoch:  1   input : 107000
# Epoch:  1   input : 107500
# Epoch:  1   input : 108000
# Epoch:  1   input : 108500
# Epoch:  1   input : 109000
# Epoch:  1   input : 109500
# Epoch:  1   input : 110000
# Epoch:  1   input : 110500
# Epoch:  1   input : 111000
# Epoch:  1   input : 111500
# Epoch:  1   input : 112000
# Epoch:  1   input : 112500
# Epoch:  1   input : 113000
# Epoch:  1   input : 113500
# Epoch:  1   input : 114000
# Epoch:  1   input : 114500
# Epoch:  1   input : 115000
# Epoch:  1   input : 115500
# Epoch:  1   input : 116000
# Epoch:  1   input : 116500
# Epoch:  1   input : 117000
# Epoch:  1   input : 117500
# Epoch:  1   input : 118000
# Epoch:  1   input : 118500
# Epoch:  1   input : 119000
# Epoch:  1   input : 119500
# Epoch:  1   input : 120000
# Epoch:  1   input : 120500
# Epoch:  1   input : 121000
# Epoch:  1   input : 121500
# Epoch:  1   input : 122000
# Epoch:  1   input : 122500
# Epoch:  1   input : 123000
# Epoch:  1   input : 123500
# Epoch:  1   input : 124000
# Epoch:  1   input : 124500
# Epoch:  1   input : 125000
# Epoch:  1   input : 125500
# Epoch:  2   input : 500
# Epoch:  2   input : 1000
# Epoch:  2   input : 1500
# Epoch:  2   input : 2000
# Epoch:  2   input : 2500
# Epoch:  2   input : 3000
# Epoch:  2   input : 3500
# Epoch:  2   input : 4000
# Epoch:  2   input : 4500
# Epoch:  2   input : 5000
# Epoch:  2   input : 5500
# Epoch:  2   input : 6000
# Epoch:  2   input : 6500
# Epoch:  2   input : 7000
# Epoch:  2   input : 7500
# Epoch:  2   input : 8000
# Epoch:  2   input : 8500
# Epoch:  2   input : 9000
# Epoch:  2   input : 9500
# Epoch:  2   input : 10000
# Epoch:  2   input : 10500
# Epoch:  2   input : 11000
# Epoch:  2   input : 11500
# Epoch:  2   input : 12000
# Epoch:  2   input : 12500
# Epoch:  2   input : 13000
# Epoch:  2   input : 13500
# Epoch:  2   input : 14000
# Epoch:  2   input : 14500
# Epoch:  2   input : 15000
# Epoch:  2   input : 15500
# Epoch:  2   input : 16000
# Epoch:  2   input : 16500
# Epoch:  2   input : 17000
# Epoch:  2   input : 17500
# Epoch:  2   input : 18000
# Epoch:  2   input : 18500
# Epoch:  2   input : 19000
# Epoch:  2   input : 19500
# Epoch:  2   input : 20000
# Epoch:  2   input : 20500
# Epoch:  2   input : 21000
# Epoch:  2   input : 21500
# Epoch:  2   input : 22000
# Epoch:  2   input : 22500
# Epoch:  2   input : 23000
# Epoch:  2   input : 23500
# Epoch:  2   input : 24000
# Epoch:  2   input : 24500
# Epoch:  2   input : 25000
# Epoch:  2   input : 25500
# Epoch:  2   input : 26000
# Epoch:  2   input : 26500
# Epoch:  2   input : 27000
# Epoch:  2   input : 27500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-409-3cf2973266ff> in <module>()
#       6 data=zip(input_col,datalabels)
#       7
# ----> 8 sp.train(data)
#       9
#      10
#
# <ipython-input-408-e7aed48337e3> in train(self, data)
#     314                 for key,value in self.weight.iteritems():
#     315                     if self.avg.has_key(key):
# --> 316                         self.avg[key]+=self.weight[key]
#     317                     else:
#     318                         self.avg[key]=self.weight[key]
#
# KeyboardInterrupt:

# %%
with open('weightTotalTrain.text','w') as f:
    f.write(str(sp.weight))
# sp.weight

# %%
def evaluate(label,given,qtys,qtye,name,unit,comment):
    global correct_sentence
    global heatmap
    global correct_one_wrong
    correct_words=0
    _qtys=0
    _qtye=0
    flagqs=0
    flagqe=0
    fractions={'1/2':0.5,'3/4':0.75,'1/4':0.25,'1/8':0.125,'1/3':0.33,'2/3':0.66}
    for i in range(len(label)):
        if label[i]=='qtys':
            if fractions.has_key(given[i]):
                _qtys=_qtys+fractions[given[i]]
            else:
                _qtys=_qtys+int(given[i])
            correct_words=correct_words+1
            if label[i+1]=='qtys':
                if fractions.has_key(given[i]):
                    _qtys=_qtys+fractions[given[i]]
                else:
                    _qtys=_qtys+int(given[i])
                correct_words=correct_words+1
                i=i+2
                
            if _qtys==qtys:
                heatmap[0,0]=heatmap[0,0]+1

                
        if label[i]=='qtye':
            if fractions.has_key(given[i]):
                _qtye=_qtye+fractions[given[i]]
            else:
                _qtye=_qtye+int(given[i])
            
            correct_words=correct_words+1
            
            if label[i+1]=='qtys':
                if fractions.has_key(given[i]):
                    _qtye=_qtye+fractions[given[i]]
                else:
                    _qtye=_qtye+int(given[i])
                correct_words=correct_words+1
                i=i+2
                
            if _qtye==qtye:
                heatmap[1,1]=heatmap[1,1]+1

                
        
        if label[i]=='name':
            if given[i] in name:
                heatmap[3,3]=heatmap[3,3]+1
                correct_words=correct_words+1
            elif given[i] in unit :
                heatmap[3,2]=heatmap[3,2]+1
            elif given[i] in comment :
                heatmap[3,4]=heatmap[3,4]+1
        elif label[i]=='unit':
            if given[i] in name:
                heatmap[2,3]=heatmap[2,3]+1
            elif given[i] in unit :
                heatmap[2,2]=heatmap[2,2]+1
                correct_words=correct_words+1
            elif given[i] in comment :
                heatmap[2,4]=heatmap[2,4]+1
        elif label[i]=='comment':
            if given[i] in name:
                heatmap[4,3]=heatmap[4,3]+1
            elif given[i] in unit :
                heatmap[4,2]=heatmap[4,2]+1
            elif given[i] in comment :
                heatmap[4,4]=heatmap[4,4]+1
                correct_words=correct_words+1
      
#     print 'correct_words: ', correct_words, '  label Len: ', len(label)
    if correct_words==len(label):
        correct_sentence=correct_sentence+1
    if correct_words+1==len(label):
        correct_one_wrong+=1

# %%
test_input_col=input_col
test_name_col=name_col
test_comment_col=comment_col
test_unit_col=unit_col
test_qtys_col=qtys_col
test_qtye_col=qtye_col
heatmap=np.matrix(np.zeros((5,5)))
correct_sentence=0
correct_one_wrong=0

result=[]
for i in range(0,len(test_input_col)):
    label=sp.test(test_input_col[i])
    result.append({'label':label,'Given':test_input_col[i],'QtyStart':test_qtys_col[i] ,'QtyEnd': test_qtye_col[i],'Name':test_name_col[i],'Unit':test_unit_col[i],'Comment':test_comment_col[i]})
#     print 'prediction: \n',label
#     print 'Given: \n',test_input_col[i],'\nQty Start: ', test_qtys_col[i] ,'\nQty End: ', test_qtye_col[i],'\n Name: ',test_name_col[i],'\n Unit:',test_unit_col[i],'\n Comment',test_comment_col[i]
    evaluate(label=label,given=test_input_col[i],qtys=test_qtys_col[i],qtye=test_qtye_col[i],name=test_name_col[i],unit=test_unit_col[i],comment=test_comment_col[i])

with open('trainResultSPTotalData.txt', 'w') as fb:
        fb.write(str(result))    
    
#Train Results
print heatmap.astype(int)
print correct_sentence
print 'Correct but one wrong: ', correct_one_wrong
print len(test_input_col)
print 'Train Sentence Accuracy: ', 1.0*correct_sentence/len(test_input_col)
# Out:
# C:\Users\SANKET\Anaconda2\envs\myenv\lib\site-packages\ipykernel_launcher.py:256: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# C:\Users\SANKET\Anaconda2\envs\myenv\lib\site-packages\ipykernel_launcher.py:257: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# [[ 99505      0      0      0      0]
#  [     0    110      0      0      0]
#  [     0      0  86428   1006   2728]
#  [     0      0   1208 194858  34621]
#  [     0      0   3140  32697 189259]]
# 67340
# Correct but one wrong:  26317
# 125943
# Train Sentence Accuracy:  0.534686326354

# %%
data= pd.read_csv('../nyt_test.csv')
with open('../stopwords.txt','r') as f:
    stopwords=f.readlines()
    stopwords=[word.strip('\n') for word in stopwords]

input_col=data['input']
# input_col=[nm.strip('\n') for nm in input_col]
input_col=[str(nm).lower() for nm in input_col]
input_col=[nm.split(' ') for nm in input_col]
input_col=[[word.strip('\t') for word in nm] for nm in input_col]
input_col=[[word.strip('_') for word in nm] for nm in input_col]
input_col=[[word.strip(',') for word in nm] for nm in input_col]
input_col=[[word.strip('/') for word in nm] for nm in input_col]
input_col=[[word.strip(')') for word in nm] for nm in input_col]
input_col=[[word.strip('(') for word in nm] for nm in input_col]
input_col=[[word.strip("'") for word in nm] for nm in input_col]
input_col=[[word.strip('\n') for word in nm] for nm in input_col]
# input_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in input_col]
input_col=[[stem(word) for word in ls] for ls in input_col]
# input_col=[[word for word in ls] for ls in input_col]
# input_col

name_col=data['name']
nameCountMap={}
name_col=[str(nm).lower() for nm in name_col]
name_col=[nm.split(' ') for nm in name_col]
name_col=[[word.strip('\t') for word in nm] for nm in name_col]
name_col=[[word.strip(' ') for word in nm] for nm in name_col]
name_col=[[word.strip(',') for word in nm] for nm in name_col]
name_col=[[word.strip('/') for word in nm] for nm in name_col]
name_col=[[word.strip(')') for word in nm] for nm in name_col]
name_col=[[word.strip('(') for word in nm] for nm in name_col]
name_col=[[word.strip("'") for word in nm] for nm in name_col]
name_col=[[word.strip('\n') for word in nm] for nm in name_col]
# name_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in name_col]
name_col=[[stem(word) for word in ls ] for ls in name_col]
word_list_name=[word for ls in name_col for word in ls]


unit_col=data['unit']
unit_col=[str(nm).lower() for nm in unit_col]
unit_col=[nm.split(' ') for nm in unit_col]
unit_col=[[word.strip('\t') for word in nm] for nm in unit_col]
unit_col=[[word.strip(' ') for word in nm]for nm in unit_col]
unit_col=[[word.strip(',') for word in nm] for nm in unit_col]
unit_col=[[word.strip('/') for word in nm] for nm in unit_col]
unit_col=[[word.strip(')') for word in nm] for nm in unit_col]
unit_col=[[word.strip('(') for word in nm] for nm in unit_col]
unit_col=[[word.strip("'") for word in nm] for nm in unit_col]
unit_col=[[word.strip('\n') for word in nm] for nm in unit_col]
# unit_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in unit_col]
unit_col=[[stem(word) for word in ls ] for ls in unit_col]
word_list_unit=[word for ls in unit_col for word in ls]# unit_col


comment_col=data['comment']
comment_col=[str(nm).lower() for nm in comment_col]
comment_col=[nm.split(' ') for nm in comment_col]
comment_col=[[word.strip('\t') for word in nm] for nm in comment_col]
comment_col=[[word.strip(' ') for word in nm] for nm in comment_col]
comment_col=[[word.strip(',') for word in nm] for nm in comment_col]
comment_col=[[word.strip('/') for word in nm] for nm in comment_col]
comment_col=[[word.strip(')') for word in nm] for nm in comment_col]
comment_col=[[word.strip('(') for word in nm] for nm in comment_col]
comment_col=[[word.strip("'") for word in nm] for nm in comment_col]
comment_col=[[word.strip('\n') for word in nm] for nm in comment_col]
# comment_col=[[stem(word) for word in ls if word not in stopwords  ] for ls in comment_col]
comment_col=[[stem(word) for word in ls ] for ls in comment_col]
word_list_comment=[word for ls in comment_col for word in ls]

qtys_col=data['qty']
qtys_col=[nm for nm in qtys_col]

qtye_col=data['range_end']
qtye_col=[nm for nm in qtye_col]

# %%
test_input_col=input_col
test_name_col=name_col
test_comment_col=comment_col
test_unit_col=unit_col
test_qtys_col=qtys_col
test_qtye_col=qtye_col

heatmap=np.matrix(np.zeros((5,5)))
correct_sentence=0
correct_one_wrong=0
result=[]
for i in range(0,len(test_input_col)):
    label=sp.test(test_input_col[i])
    result.append({'label':label,'Given':test_input_col[i],'QtyStart':test_qtys_col[i] ,'QtyEnd': test_qtye_col[i],'Name':test_name_col[i],'Unit':test_unit_col[i],'Comment':test_comment_col[i]})
#     print 'prediction: \n',label
#     print 'Given: \n',test_input_col[i],'\nQty Start: ', test_qtys_col[i] ,'\nQty End: ', test_qtye_col[i],'\n Name: ',test_name_col[i],'\n Unit:',test_unit_col[i],'\n Comment',test_comment_col[i]
    evaluate(label=label,given=test_input_col[i],qtys=test_qtys_col[i],qtye=test_qtye_col[i],name=test_name_col[i],unit=test_unit_col[i],comment=test_comment_col[i])

with open('testResultSP.txt', 'w') as fb:
        fb.write(str(result))    
    
#Train Results
print heatmap.astype(int)
print correct_sentence
print 'Correct but one wrong: ', correct_one_wrong
print len(test_input_col)
print 'Test Sentence Accuracy: ', 1.0*correct_sentence/len(test_input_col)
# Out:
# C:\Users\SANKET\Anaconda2\envs\myenv\lib\site-packages\ipykernel_launcher.py:257: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# C:\Users\SANKET\Anaconda2\envs\myenv\lib\site-packages\ipykernel_launcher.py:256: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# [[42048     0     0     0     0]
#  [    0    29     0     0     0]
#  [    0     0 36463   463  1115]
#  [    0     0   539 82008 14987]
#  [    0     0  1334 13806 81522]]
# 28170
# Correct but one wrong:  11309
# 53120
# Test Sentence Accuracy:  0.53030873494
